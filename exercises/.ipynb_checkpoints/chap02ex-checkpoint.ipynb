# %% [markdown]
# Exercise from Think Stats, 2nd Edition (thinkstats2.com)<br>
# Allen Downey
#
# Read the female respondent file and display the variables names.

# %%
import pandas as pd
import matplotlib as plt
import math
# %matplotlib inline
plt.style.use('ggplot')

# %%
import chap02
resp = chap02.ReadFemResp()

# %% [markdown]
# Make a histogram of <tt>totincr</tt> the total income for the respondent's family.  To interpret the codes see the [codebook](http://www.icpsr.umich.edu/nsfg6/Controller?displayPage=labelDetails&fileCode=MALE&section=R&subSec=7958&srtLabel=609776).

# %%
totincr = resp.totincr
df = pd.DataFrame(totincr)

# %% [markdown]
# code | max income
# --- | ---
# 1 | 5000
# 2 | 7499
# 3 | 9999
# 4 | 12,499
# 5 | 14,999
# 6 | 19,999
# 7 | 24,999
# 8 | 29,999
# 9 | 34,999
# 10 | 39,999
# 11 | 49,999
# 12 | 59,999
# 13 | 74,999
# 14 | > $75,000

# %% [markdown]
# Display the histogram.

# %%
df.plot(kind='hist', bins=14) # 14 total codes, hence 14 bins

# %% [markdown]
# Make a histogram of <tt>age_r</tt>, the respondent's age at the time of interview.

# %%
age_r = resp.age_r
df = pd.DataFrame(age_r)
df.plot(kind='hist', bins=30)

# %% [markdown]
# Make a histogram of <tt>numfmhh</tt>, the number of people in the respondent's household.

# %%
num = resp.numfmhh
df = pd.DataFrame(num)
num.plot(kind='hist', bins=8)

# %% [markdown]
# Make a histogram of <tt>parity</tt>, the number children the respondent has borne.  How would you describe this distribution?

# %%
parity = resp.parity
df = pd.DataFrame(parity)
df.plot(kind='hist', bins=10)

# %% [markdown]
# Use Hist.Largest to find the largest values of <tt>parity</tt>.

# %%
parity.nlargest(10)
# Out:
# 715     22
# 5339    16
# 682     10
# 3053    10
# 5338    10
# 2444     9
# 3141     9
# 933      8
# 1669     8
# 1871     8
# Name: parity, dtype: int64

# %% [markdown]
# Use <tt>totincr</tt> to select the respondents with the highest income.  Compute the distribution of <tt>parity</tt> for just the high income respondents.

# %%
high_inc = parity[totincr == 14]
df = pd.DataFrame(high_inc)
df.plot(kind='hist', bins=10)

# %% [markdown]
# Find the largest parities for high income respondents.

# %%
high_inc.nlargest(10)
# Out:
# 2445    8
# 6615    7
# 878     5
# 1659    5
# 2172    5
# 2587    5
# 4274    5
# 425     4
# 426     4
# 553     4
# Name: parity, dtype: int64

# %% [markdown]
# Compare the mean <tt>parity</tt> for high income respondents and others.

# %%
not_high_inc = parity[totincr != 14]

print not_high_inc.mean()
print high_inc.mean()
# Out:
# 1.24957581367
# 1.07586206897

# %% [markdown]
# Investigate any other variables that look interesting.

# %%
def CohenEffectSize(group1, group2):
    diff = group1.mean() - group2.mean() # difference in means of group 1 and group 2

    var1 = group1.var() # variability of group 1
    var2 = group2.var() # '' of group 2
    n1, n2 = len(group1), len(group2) # sample size of groups 1 and 2

    # pooled variability is equal to sample size of group 1 times variability of group 1, plus sample size of group 2 times variability of group 2, all over combined sample size of groups 1 and 2
    pooled_var = (n1 * var1 + n2 * var2) / (n1 + n2)
    # d is equal to the difference in means of group 1 and group 2 over the square root of their pooled variability
    d = diff / math.sqrt(pooled_var)
    return d

CohenEffectSize(not_high_inc, high_inc)
# Out:
# 0.1251185531466061

# %% [markdown]
# Cohen's d is .12 standard deviations, or small.
